# %% [markdown]
# **References**: https://github.com/blockchain-etl/ethereum-etl

# %% [markdown]
# # Problem Set 1 Checklist

# %% [markdown]
# **Please customize the following inputs to generate your own results for discussion**
#
#
# * Infura/Alchemy/QuickNode API endpoints: experiment with multiple node operators and see if you could get the same data
#
# * Data radius, start, and end blocks: pick a smaller radius for testing before you scale
#
# * Token address: Pick your choice of token in querying the token transfer part
#
# **Please post the sharing (Allow viewing or commenting only) URL for your Google Colab after you are done below.**
#
# Important: Change your private API token key to "API_KEY" before posting

# %% [markdown]
# ## Question 1 (5 points)
# Did you get the same data querying via different node operators? Please point to at least one specific observation to validate your answer.
#
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# I used QuickNode and Alchemy to do the data querying. After choosing a set of three blocks, the files are saved to Google Drive under different names. To evaluate the equvilancy, I ran a python commmand to compare the contents of each cell:
# ![Screen Shot 2023-01-29 at 8.50.41 PM.png](data:image/png;base64,...)
#
# As you can see, the contents of the files are the same for every cell, meaning the data that was queried has the same value.

# %% [markdown]
# ## Question 2 (5 points)

# %% [markdown]
# Please introduce the ERC20 token that you queried in 100 words:
#
#
# *   when the token first was issued?
# *   what functions do the token support?
# *   what is the current market value of the token?
# *   Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer.
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# 1. The SAND token was first introduced in August of 2020
# 2. The tokens can be used to buy things in The Sandbox, mainly 3D objects. Sand is used to easily facilitate the payment for buying and selling these creations.
# 3. As of today, the token has a market value of $ 0.789706
#
# Here is some example transaction data for the token:
#
# |index|token\_address|from\_address|to\_address|value|transaction\_hash|log\_index|block\_number|
# |---|---|---|---|---|---|---|---|
# |0|0x3845badade8e6dff049820680d1f14bd3903a5d0|0x21a31ee1afc51d94c2efccaa2092ad1028285549|0x9969103f649c54873728897d525c18fbb27202fa|301567000000000000000|0xd90f1ef0ba6f761286f34d77eeb6388f9504b8e50535e209a02836ea1c15f96d|187|16512450|
# |1|0x3845badade8e6dff049820680d1f14bd3903a5d0|0x48c04ed5691981c42154c6167398f95e8f38a7ff|0x4f96b78290c0cd75c660b694f71f86e592101c9a|10054505040000000000|0x46ecf4198a7f1b7f90729bf77decab6b0199750e1416996174f2ada40ae29553|43|16512454|
# |2|0x3845badade8e6dff049820680d1f14bd3903a5d0|0xa9d1e08c7793af67e9d92fe308d5697fb81d3e43|0x41b127daa1ba7ebbbcf021308e2e30a9779e9cfb|50000000000000000000|0x18cc2089becb57f59f5f307d8de2991aad6e93a3ac70ea5d9dbfe18a2da09a43|76|16512456|
# |3|0x3845badade8e6dff049820680d1f14bd3903a5d0|0xf5f9503e0a4553a1b2d9bde2977ffbb142582b83|0x92a25c8420f777f8553b02a19b1c2b55b4872a1d|7152188096470000000000|0x37c1a2d17e17800732a087abfe4d632b867b465faa7c5779d52af93da9b925bc|402|16512460|
# |4|0x3845badade8e6dff049820680d1f14bd3903a5d0|0x8b78a7fbedd40cf90df567f384931eee1aa44525|0x7a9fe22691c811ea339d9b73150e6911a5343dca|70000000000000000000|0xef30e79cbbf87c4ea7d1f42d6ebbfd1275bde840f1063ab1118a97fa05c79e6b|157|16512464|

# %% [markdown]
# https://arxiv.org/pdf/2202.03081.pdf
#
# ```
# @article{Nakavachara2022IsML,
#   title={Is Metaverse LAND a good investment? It depends on your unit of account!},
#   author={Voraprapa Nakavachara and Kanis Saengchote},
#   journal={SSRN Electronic Journal},
#   year={2022}
# }
# ```
#
# The background for this paper is that while the price for LAND NFT increased over 300 dollars USD, when compared with SAND, the native token, it only increased three times. The paper hopes to answer why people's spending habits place a higher value on a token like SAND as opposed to a smart ETH contract, and help describe people's spending habits. The research question, more specifically, is how does paying for an item in SAND as opposed to another method affect people's spending when both are compared to the US dollar. Over 50,000 transactions were analyzed to discover that people were willing to pay 3-4% more to settle a transaction in SAND. These results help reveal information to the field of buying habits in cryptocurrency.

# %% [markdown]
# ### Question 3: (5 points)
#
# Please introduce the ERC721 token that you queried in 100 words:
#
#
# *   when the token first was issued?
# *   what functions do the token support?
# *  what is the current market value of the token?
# *   Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer.
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# 1. The token was first introduced in 2017, where 10,000 of them were minted. The developers mainly created them as an interesting project only.
# 2. The tokens are 24×24-pixel images that are computer generated with different aspects. They are traded as art pieces.
# 3. Since tokens are unique, there is no going market rate for value of a token, but there have been ones that have sold for over 20 million USD. Here's one example of a transaction:
#
# |index|token\_address|from\_address|to\_address|value|transaction\_hash|log\_index|block\_number|
# |---|---|---|---|---|---|---|---|
# |0|0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb|0x1ab2e5ddd5a09142fed3e1969ccd9f9989baa6de|0xbdf1cdd4102d69735f2a1c50971a06f828a46294|1|0x064470c028eeae748e84c04deb85b79b69cc5cadd661c9cc193549d744618c56|163|16503239|
#
# The current floor price is about 64 ETH, and the average sale price is 75 ETH.
#
# https://jbba.scholasticahq.com/article/31949.pdf
#
# The background for this paper is that NFT's have gathered a lot of attention from investors seeking alternate investments. The research question is: How does CryptoPunks compare to other more typical financial assets in terms of diversification and performance. This is the first paper of its kind to compare these two in such a manner. The authors used a number of traditional financial benchmarks to compare the categories of assets to discover that CryptoPunks would have made a good investment over the study period, outpreforming traditional investments. The conclusion is that cryptocurrency assests can be a viable form of investment, and can be diverse.

# %% [markdown]
# # Part I: Install Required Dependancies

# %% [markdown]
# # install ethereum-etl and pandas
# !python -m pip install ethereum-etl pandas
# # Setup
# from web3 import Web3
#
# alchemy_url = "https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys"
# w3 = Web3(Web3.HTTPProvider(alchemy_url))
#
# # Print if web3 is successfully connected
# print(w3.isConnected())
#
# # Get the latest block number
# latest_block = w3.eth.block_number
# print(latest_block)

# %% [markdown]
# # Part II: Mount Google Drive for Result Exports

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# print the current directory
# !pwd
# Out:
# /content/drive/My Drive/PolygonExample

# %%
#@title path
#create a project folder and identify the path
path = "/content/drive/MyDrive/EthereumETL" #@param {type:"string"}

# %%
#go to your project folder 
# %cd /content/drive/MyDrive/PolygonExample
# Out:
# /content/drive/MyDrive/PolygonExample

# %%
# print the current directory again to make sure that you are in the project folder
# !pwd
# Out:
# /content/drive/My Drive/PolygonExample

# %% [markdown]
# # Part III: Query Data and Export CSV

# %% [markdown]
# ## 0.Register Accounts on Remote Nodes Service and Get the URLs of the Nodes

# %% [markdown]
# ### Remote node option 1: Infura

# %% [markdown]
# !!! Important Notes: Please replace https://mainnet.infura.io/v3/API_KEY with your own endpoints for all the codes below

# %%
#@title Import using the Infura node
infura_end_points_URL = "https://mainnet.infura.io/v3/API_KEY" #@param {type:"string"}

# %% [markdown]
# ### Remote node option 2: Alchemy

# %%
#@title import using Alchemy
alchemy_end_points_URL = "https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys" #@param {type:"string"}

# %% [markdown]
# ### Remote node option 3: QuickNode

# %%
#@title import using QuickNode
QuickNode_end_points_URL = "https://small-evocative-gas.discover.quiknode.pro/4cfc526cff0c57d8f00eacd566eebf70c422ed04/" #@param {type:"string"}

# %% [markdown]
# Data Range: We are going to query the block and transaction data for the ethereum blockchain before and after the merge (block number: 15537393 on September 15)
#
# Reference;
# https://www.investopedia.com/ethereum-completes-the-merge-6666337

# %%
#@title the merge
merge = 16512498 #@param {type:"number"}

# %%
#@title data radius
radius = 1 #@param {type:"number"}

# %%
### find the start and the end
start = merge-radius
end = merge+radius
print(start, end)
# Out:
# 16512497 16512499

# %% [markdown]
# ## 1. Query Block Data

# %% [markdown]
# ### using the infura endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 16512497 --end-block 16512499 --blocks-output blocks.csv --provider-uri https://mainnet.infura.io/v3/API_KEY
# Out:
# 2022-11-09 14:07:41,682 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2022-11-09 14:07:43,013 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2022-11-09 14:07:43,262 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2022-11-09 14:07:43,263 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:01.580403.
# 2022-11-09 14:07:43,264 - CompositeItemExporter [INFO] - block items exported: 201
# 2022-11-09 14:07:43,264 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
# import libraries to print data frame
import pandas as pd

# %%
# set to print the maximum numbers of rows
pd.set_option('display.max_rows', None)

# %%
df_blocks = pd.read_csv('./blocks.csv')
display(df_blocks.head(10))
# Out:
#      number                                               hash  \
# 0  15537493  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...
# 1  15537393  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...
# 2  15537394  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...
# 3  15537395  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...
# 4  15537396  0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b29...
# 5  15537397  0x9797d65f12465ada68cdacf7e6b7c22fe43a4d096711...
# 6  15537398  0xb21c38c1c3ee6ae142fa03ae2671db768da478f03bd7...
# 7  15537399  0x1120a11900f39be011ef8b5264c06c4d32837fd01ded...
# 8  15537400  0xcba6f4349a71f20cd86dcb3e804b73c69e5e16d735dc...
# 9  15537401  0xa566c95004ef66dc45c048ef39a7017c7365c4b2dd0e...
#
#                                          parent_hash               nonce  \
# 0  0x3dabb8d96bfc2dfeef5fad9be48afdb90a0d9011865d...  0x0000000000000000
# 1  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...  0x62a3ee77461d4fc9
# ...

# %% [markdown]
# ### query blockchain data using the alchemy endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 16512497 --end-block 16512499 --blocks-output blocks_alchemy.csv --provider-uri https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys
# Out:
# 2023-01-29 12:39:13,289 - ProgressLogger [INFO] - Started work. Items to process: 3.
# 2023-01-29 12:39:13,483 - ProgressLogger [INFO] - 3 items processed. Progress is 100%.
# 2023-01-29 12:39:13,483 - ProgressLogger [INFO] - Finished work. Total items processed: 3. Took 0:00:00.194170.
# 2023-01-29 12:39:13,485 - CompositeItemExporter [INFO] - block items exported: 3
# 2023-01-29 12:39:13,485 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_alchemy = pd.read_csv('./blocks_alchemy.csv')
display(df_blocks_alchemy.head(10))
# Out:
#      number                                               hash  \
# 0  16512497  0x3a67f31b76b2a9317f3fd212e346c830ad595ed9d86f...
# 1  16512498  0xef4528693034adeb0647258592d9b7378c7134ed5b86...
# 2  16512499  0x4fc7968b3b665bc80c91d7c85383cd4bac8e27790579...
#
#                                          parent_hash               nonce  \
# 0  0x01f868418a2ca404de43d3764e9251731a8b9954d4ac...  0x0000000000000000
# 1  0x3a67f31b76b2a9317f3fd212e346c830ad595ed9d86f...  0x0000000000000000
# 2  0xef4528693034adeb0647258592d9b7378c7134ed5b86...  0x0000000000000000
#
#                                          sha3_uncles  \
# 0  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# 1  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# 2  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
#
#                                           logs_bloom  \
# 0  0x75fd112776009a0b306a92ac9919008008842eb2c802...
# 1  0x00a981689630582d9cca50a0cb10036219220848c912...
# ...

# %%
# !ethereumetl export_blocks_and_transactions --start-block 1 --end-block 2 --blocks-output blocks_one.csv --provider-uri https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys
# Out:
# 2023-01-29 14:08:40,977 - ProgressLogger [INFO] - Started work. Items to process: 2.
# 2023-01-29 14:08:41,175 - ProgressLogger [INFO] - 2 items processed. Progress is 100%.
# 2023-01-29 14:08:41,175 - ProgressLogger [INFO] - Finished work. Total items processed: 2. Took 0:00:00.197772.
# 2023-01-29 14:08:41,178 - CompositeItemExporter [INFO] - block items exported: 2
# 2023-01-29 14:08:41,178 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_alchemy = pd.read_csv('./blocks_one.csv')
display(df_blocks_alchemy.head(10))
# Out:
#    number                                               hash  \
# 0       1  0x88e96d4537bea4d9c05d12549907b32561d3bf31f45a...
# 1       2  0xb495a1d7e6663152ae92708da4843337b958146015a2...
#
#                                          parent_hash               nonce  \
# 0  0xd4e56740f876aef8c010b86a40d5f56745a118d0906a...  0x539bd4979fef1ec4
# 1  0x88e96d4537bea4d9c05d12549907b32561d3bf31f45a...  0xb853fa261a86aa9e
#
#                                          sha3_uncles  \
# 0  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# 1  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
#
#                                           logs_bloom  \
# 0  0x00000000000000000000000000000000000000000000...
# 1  0x00000000000000000000000000000000000000000000...
#
#                                    transactions_root  \
# 0  0x56e81f171bcc55a6ff8345e692c0f86e5b48e01b996c...
# 1  0x56e81f171bcc55a6ff8345e692c0f86e5b48e01b996c...
#
#                                           state_root  \
# ...

# %% [markdown]
# ### query the data using the QuickNode endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 16512497 --end-block 16512499 --blocks-output blocks_QuickNode.csv --provider-uri https://small-evocative-gas.discover.quiknode.pro/4cfc526cff0c57d8f00eacd566eebf70c422ed04/
# Out:
# 2023-01-29 12:40:39,485 - ProgressLogger [INFO] - Started work. Items to process: 3.
# 2023-01-29 12:40:39,688 - ProgressLogger [INFO] - 3 items processed. Progress is 100%.
# 2023-01-29 12:40:39,689 - ProgressLogger [INFO] - Finished work. Total items processed: 3. Took 0:00:00.203649.
# 2023-01-29 12:40:39,691 - CompositeItemExporter [INFO] - block items exported: 3
# 2023-01-29 12:40:39,691 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_QuickNode = pd.read_csv('./blocks_QuickNode.csv')
display(df_blocks_QuickNode.head(10))
# Out:
#      number                                               hash  \
# 0  16512497  0x3a67f31b76b2a9317f3fd212e346c830ad595ed9d86f...
# 1  16512498  0xef4528693034adeb0647258592d9b7378c7134ed5b86...
# 2  16512499  0x4fc7968b3b665bc80c91d7c85383cd4bac8e27790579...
#
#                                          parent_hash               nonce  \
# 0  0x01f868418a2ca404de43d3764e9251731a8b9954d4ac...  0x0000000000000000
# 1  0x3a67f31b76b2a9317f3fd212e346c830ad595ed9d86f...  0x0000000000000000
# 2  0xef4528693034adeb0647258592d9b7378c7134ed5b86...  0x0000000000000000
#
#                                          sha3_uncles  \
# 0  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# 1  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# 2  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
#
#                                           logs_bloom  \
# 0  0x75fd112776009a0b306a92ac9919008008842eb2c802...
# 1  0x00a981689630582d9cca50a0cb10036219220848c912...
# ...

# %% [markdown]
# ## 2. Query Transaction Data

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537293 --end-block 15537493 --transactions-output transactions.csv --provider-uri https://mainnet.infura.io/v3/API_KEY
# Out:
# 2022-11-09 14:07:55,755 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2022-11-09 14:08:03,328 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2022-11-09 14:08:03,907 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2022-11-09 14:08:03,907 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:08.151989.
# 2022-11-09 14:08:03,908 - CompositeItemExporter [INFO] - block items exported: 0
# 2022-11-09 14:08:03,909 - CompositeItemExporter [INFO] - transaction items exported: 26358

# %%
df_transactions = pd.read_csv('./transactions.csv')
display(df_transactions.head())
# Out:
#                                                 hash  nonce  \
# 0  0xe683eda92e8b18c95c23e8a8dc64256b1d02110401ae...     14
# 1  0x3448496be0ce2563f06f96f72fd821bd2b7ba6c86bd3...   9142
# 2  0x25a16381da87716c076f1fbb79f042c4fe0bdb3653d5...  15300
# 3  0x443ded6693eb3ba793d6fe106bf2cccaa1d23bd58470...   5488
# 4  0x711102faeba142f270b6a08d5be26059902c5d297da6...     96
#
#                                           block_hash  block_number  \
# 0  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...      15537493
# 1  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...      15537493
# 2  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...      15537493
# 3  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...      15537493
# 4  0x0ac7d9aa5886b66b8bdc217a2dd06d3393d6712c7486...      15537493
#
#    transaction_index                                from_address  \
# 0                  0  0x035baccc3c7daed66211f54e0077e69a2eaeefdc
# 1                  1  0x7dacfce9eacdca48cad5ba0b61560586c375890b
# ...

# %% [markdown]
# ## 3. Query Token Data

# %% [markdown]
# ### 3.1 Query All Token Transfers

# %%
# !ethereumetl export_token_transfers --start-block 16512487 --end-block 16512497 --provider-uri https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys --output token_transfers.csv
# Out:
# 2023-01-29 13:35:40,629 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-29 13:35:41,374 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-29 13:35:41,375 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:00.745476.
# 2023-01-29 13:35:41,377 - CompositeItemExporter [INFO] - token_transfer items exported: 917

# %%
df_token_transfers = pd.read_csv('./token_transfers.csv')
display(df_token_transfers.head())
# Out:
#                                 token_address  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1  0xdac17f958d2ee523a2206206994597c13d831ec7
# 2  0xdd0ef0b2de3efec847a79b4ce4de52c4bb98f488
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                  from_address  \
# 0  0x11b815efb8f581194ae79006d24e0d814b7697f6
# 1  0x369ccbcd7c55fe89fa3b05a701d7fa3cfc3fa157
# 2  0x314719bf2fd9b60e0682514e45189716ba654e71
# 3  0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45
# 4  0x314719bf2fd9b60e0682514e45189716ba654e71
#
#                                    to_address                  value  \
# 0  0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45     248882574782780965
# 1  0x11b815efb8f581194ae79006d24e0d814b7697f6              400000000
# 2  0x369ccbcd7c55fe89fa3b05a701d7fa3cfc3fa157  255364555755289239752
# 3  0x314719bf2fd9b60e0682514e45189716ba654e71     248882574782780965
# ...

# %%
df = df_token_transfers[df_token_transfers.token_address=="0x3845badade8e6dff049820680d1f14bd3903a5d0"]
df.head()
# Out:
#                                   token_address  \
# 70   0x3845badade8e6dff049820680d1f14bd3903a5d0
# 71   0x3845badade8e6dff049820680d1f14bd3903a5d0
# 72   0x3845badade8e6dff049820680d1f14bd3903a5d0
# 744  0x3845badade8e6dff049820680d1f14bd3903a5d0
# 745  0x3845badade8e6dff049820680d1f14bd3903a5d0
#
#                                    from_address  \
# 70   0xf8ab22d217f36f3e4c067442e0bbce128f468ac7
# 71   0xa290719a545c4ebb8e58e5d588a4e63bef5be526
# 72   0xe5782724e87bcd5a1f48737ff6cfeaf875ab5873
# 744  0xafdfe281200237a62b843ddb32b84079310ab08b
# 745  0x5b97b125cf8af96834f2d08c8f1291bd47724939
#
#                                      to_address                    value  \
# 70   0x28c6c06298d514db089934071355e5743bf21d60  70000000000000000000000
# 71   0x28c6c06298d514db089934071355e5743bf21d60  72000000000000000000000
# 72   0x28c6c06298d514db089934071355e5743bf21d60  49989750000000000000000
# 744  0x5b97b125cf8af96834f2d08c8f1291bd47724939  10000000000000000000000
# ...

# %% [markdown]
# ### 3.1 Query a specific ERC20 token transfers

# %% [markdown]
# *references*:
#
# * Commond Documentations: https://ethereum-etl.readthedocs.io/en/latest/commands/
# * Token Address: https://github.com/blockchain-etl/ethereum-etl-airflow/blob/master/dags/resources/stages/seed/data/token_amendments.csv
# * More detailed: https://github.com/blockchain-etl/ethereum-etl-airflow
# * Proof-of-Reserve: https://blog.chain.link/stablecoins-and-proof-of-reserve/

# %%
#@title Token Name
Token_Name = "SAND" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "SAND" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0x3845badAde8e6dFF049820680d1F14bD3903a5d0" #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 16512447 --end-block 16512497 --provider-uri https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys --output token_transfers_SAND.csv --tokens 0x3845badAde8e6dFF049820680d1F14bD3903a5d0
# Out:
# 2023-01-29 14:04:53,674 - ProgressLogger [INFO] - Started work. Items to process: 51.
# 2023-01-29 14:04:53,980 - ProgressLogger [INFO] - 51 items processed. Progress is 100%.
# 2023-01-29 14:04:53,980 - ProgressLogger [INFO] - Finished work. Total items processed: 51. Took 0:00:00.306502.
# 2023-01-29 14:04:53,982 - CompositeItemExporter [INFO] - token_transfer items exported: 16

# %%
df_token_transfers_SAND = pd.read_csv('./token_transfers_SAND.csv')
display(df_token_transfers_SAND.head())
# Out:
#                                 token_address  \
# 0  0x3845badade8e6dff049820680d1f14bd3903a5d0
# 1  0x3845badade8e6dff049820680d1f14bd3903a5d0
# 2  0x3845badade8e6dff049820680d1f14bd3903a5d0
# 3  0x3845badade8e6dff049820680d1f14bd3903a5d0
# 4  0x3845badade8e6dff049820680d1f14bd3903a5d0
#
#                                  from_address  \
# 0  0x21a31ee1afc51d94c2efccaa2092ad1028285549
# 1  0x48c04ed5691981c42154c6167398f95e8f38a7ff
# 2  0xa9d1e08c7793af67e9d92fe308d5697fb81d3e43
# 3  0xf5f9503e0a4553a1b2d9bde2977ffbb142582b83
# 4  0x8b78a7fbedd40cf90df567f384931eee1aa44525
#
#                                    to_address                   value  \
# 0  0x9969103f649c54873728897d525c18fbb27202fa   301567000000000000000
# 1  0x4f96b78290c0cd75c660b694f71f86e592101c9a    10054505040000000000
# 2  0x41b127daa1ba7ebbbcf021308e2e30a9779e9cfb    50000000000000000000
# 3  0x92a25c8420f777f8553b02a19b1c2b55b4872a1d  7152188096470000000000
# ...

# %% [markdown]
# ### 3.1 Query a specific ERC721 token transfers

# %% [markdown]
# 0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB

# %%
# !ethereumetl export_token_transfers --start-block 16503000 --end-block 16503699 --provider-uri https://eth-mainnet.g.alchemy.com/v2/eozy7M_4ImLJ5njQv1htbpRynF4AIuys --output token_transfers_Crypto.csv --tokens 0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB
# Out:
# 2023-01-29 14:29:10,664 - ProgressLogger [INFO] - Started work. Items to process: 700.
# 2023-01-29 14:29:10,934 - ProgressLogger [INFO] - 100 items processed. Progress is 14%.
# 2023-01-29 14:29:10,937 - ProgressLogger [INFO] - 200 items processed. Progress is 28%.
# 2023-01-29 14:29:10,941 - ProgressLogger [INFO] - 300 items processed. Progress is 42%.
# 2023-01-29 14:29:10,969 - ProgressLogger [INFO] - 400 items processed. Progress is 57%.
# 2023-01-29 14:29:10,976 - ProgressLogger [INFO] - 500 items processed. Progress is 71%.
# 2023-01-29 14:29:11,115 - ProgressLogger [INFO] - 600 items processed. Progress is 85%.
# 2023-01-29 14:29:11,125 - ProgressLogger [INFO] - 700 items processed. Progress is 100%.
# 2023-01-29 14:29:11,125 - ProgressLogger [INFO] - Finished work. Total items processed: 700. Took 0:00:00.461637.
# 2023-01-29 14:29:11,127 - CompositeItemExporter [INFO] - token_transfer items exported: 1

# %%
df_token_transfers_Crypto = pd.read_csv('./token_transfers_Crypto.csv')
display(df_token_transfers_Crypto.head())
# Out:
#                                 token_address  \
# 0  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
#
#                                  from_address  \
# 0  0x1ab2e5ddd5a09142fed3e1969ccd9f9989baa6de
#
#                                    to_address  value  \
# 0  0xbdf1cdd4102d69735f2a1c50971a06f828a46294      1
#
#                                     transaction_hash  log_index  block_number
# 0  0x064470c028eeae748e84c04deb85b79b69cc5cadd661...        163      16503239
